# %% [markdown]
# <link rel="preconnect" href="https://fonts.googleapis.com">
# <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
# <link href="https://fonts.googleapis.com/css2?family=Roboto:ital,wght@0,100..900;1,100..900&display=swap" rel="stylesheet">
#
# <div style="
#   border: 1px solid transparent;
#   border-radius: 18px;
#   background:
#     linear-gradient(#FFFFFF, #FFFFFF) padding-box,
#     conic-gradient(from 220deg,
#       #A8C5E0 0%,
#       #4682B4 25%,
#       #2C5F8A 55%,
#       #1A3D5C 75%,
#       #A8C5E0 100%
#     ) border-box;
#   padding: 50px 30px;
#   text-align: center;
#   font-family: 'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;
#   color: #333333;
#   box-shadow: 0 2px 12px rgba(0,0,0,0.08);
#   margin: 40px auto;
#   max-width: 800px;
# ">
#
#   <h1 style="
#       font-size: 2.8em;
#       font-weight: 700;
#       margin: 0 0 8px 0;
#       letter-spacing: -0.02em;
#       background: linear-gradient(90deg, #A8C5E0 20%, #4682B4 40%, #2C5F8A 60%, #1A3D5C 80%);
#       -webkit-background-clip: text;
#       -webkit-text-fill-color: transparent;
#   ">
#       RL Group Project
#   </h1>
#
#   <h2 style="
#       font-size: 1.6em;
#       font-weight: 500;
#       margin: 0 0 25px 0;
#       color: #4682B4;
#       letter-spacing: 0.5px;
#   ">
#       Clinical Treatment Optimisation — Sepsis ICU Management
#   </h2>
#
#   <p style="
#       font-size: 1.05em;
#       font-weight: 400;
#       color: #757575;
#       font-style: italic;
#       letter-spacing: 0.5px;
#       margin-bottom: 25px;
#   ">
#       Master in Data Science &amp; Advanced Analytics · Reinforcement Learning Course
#   </p>
#
#   <div style="
#       font-size: 1.0em;
#       color: #757575;
#       line-height: 1.6;
#       margin-bottom: 8px;
#   ">
#       <div>Student 1: 20250487</div>
#       <div>Student 2:</div>
#       <div>Student 3:</div>
#       <div>Student 4:</div>
#       <div>Student 5:</div>
#   </div>
#
#   <p style="
#       font-size: 0.85em;
#       color: #757575;
#       font-style: italic;
#       margin: 0 0 20px 0;
#   ">
#   </p>
#
#   <p style="
#       font-size: 1.25em;
#       font-weight: 500;
#       color: #4682B4;
#       margin: 0;
#   ">
#       Group X
#   </p>
# </div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <h3 style="margin-top: 0; margin-bottom: 10px; color: #333333; font-weight: bold;">Notebook Structure</h3>
#     <ol style="margin: 10px 40px 10px 20px; padding-left: 20px; padding-right: 0; color: #757575;">
#         <li style="margin-right: 20px; margin-bottom: 5px;"><a href="#setup" style="color: #4682B4; text-decoration: none; font-weight: 500;">0. Setup &amp; Imports</a></li>
#         <li style="margin-right: 20px; margin-bottom: 5px;"><a href="#explore-environment" style="color: #4682B4; text-decoration: none; font-weight: 500;">1. Explore the Environment</a></li>
#         <li style="margin-right: 20px; margin-bottom: 5px;"><a href="#config-a-tabular" style="color: #4682B4; text-decoration: none; font-weight: 500;">2. Config A — Tabular Methods</a></li>
#         <li style="margin-right: 20px; margin-bottom: 5px;"><a href="#config-b-funcapprox" style="color: #4682B4; text-decoration: none; font-weight: 500;">3. Config B — Function Approximation</a></li>
#         <li style="margin-right: 20px; margin-bottom: 5px;"><a href="#comparison" style="color: #4682B4; text-decoration: none; font-weight: 500;">4. Comparison of Config A and Config B</a></li>
#     </ol>
# </div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <h3 style="margin-top: 0; margin-bottom: 10px; color: #333333; font-weight: bold;">Project Overview</h3>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">This project applies reinforcement learning to ICU sepsis treatment in two stages of increasing complexity, both built on the <code>ICU-Sepsis-v2</code> MDP.</p>
#     <ul style="margin: 10px 40px 10px 20px; padding-left: 20px; padding-right: 0; color: #757575;">
#         <li style="margin-right: 20px;"><strong>Configuration A (tabular).</strong> A discrete Sepsis MDP whose state and action spaces are small enough for classical RL applied directly: value iteration, Q-learning, and SARSA.</li>
#         <li style="margin-right: 20px;"><strong>Configuration B (continuous, clinical).</strong> The same MDP exposed as a 47-dimensional continuous observation and wrapped in three clinical-reality failure modes, solved with function approximation (Linear-Q, DQN, and PPO).</li>
#     </ul>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">The three Config B failure modes (episodic observation noise, episodic missing labs, and rare acute events) are described in <strong>1. Explore the Environment</strong>.</p>
# </div>

# %% [markdown]
# # <a class='anchor' id='setup'></a>
#
# <div style="background: linear-gradient(to right, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C);
#             padding: 10px; color: white; text-align: center; max-width: 98%;">
#     <center><h1 style="margin-top: 10px; margin-bottom: 4px; color: white;
#                        font-size: 32px; font-family: 'Roboto', 'Segoe UI', sans-serif;">
#         <b>0. Setup &amp; Imports</b></h1></center>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import warnings
import os
import sys

import contextlib
import io

warnings.filterwarnings('ignore')
sns.set_theme(style='whitegrid', palette='muted')
plt.rcParams['figure.dpi'] = 110

os.makedirs('plots', exist_ok=True)
PLOTS_DIR = 'plots'

SEED = 42
np.random.seed(SEED)

import copy

from envs.env_setup import (
    ENV_ID, N_STATES, N_ACTIONS, STATE_SURVIVED, STATE_DIED,
    GAMMA, INTENSITY, SOFA_BIAS, LAM,
    make_sepsis_env,
)
from envs.wrappers import (
    EpisodicNoisyObsEnv,
    EpisodicMissingObsEnv,
    AcuteEventEnv,
    make_clinical_env,
)
from envs.continuous_sepsis_env import ContinuousICUSepsisEnv, FEATURE_NAMES
from rl_utils import (
    set_global_seeds, make_clinical_env_quiet,
    evaluate_policy, evaluate_agent, evaluate_tabular_on_clinical,
    run_random_baseline, random_predict,
    subset_survival, bootstrap_survival_ci,
    rolling_mean, mean_curve, steps_to_threshold, fmt_conv, best_run,
    plot_learning_curve,
    policy_action_counts, policy_action_grid, action_by_sofa,
)

import torch
from stable_baselines3 import DQN, PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.utils import set_random_seed

# Config B training budget. CONFIGB_TOTAL_STEPS env var allows a fast smoke run.
SEEDS_B = [0, 1, 2]
TOTAL_STEPS = int(os.environ.get('CONFIGB_TOTAL_STEPS', '150000'))
SNAP_EVERY_B = max(1000, TOTAL_STEPS // 15)

print(f'ICU-Sepsis-v2 | States: {N_STATES} | Actions: {N_ACTIONS}')
print(f'Terminal states: {STATE_SURVIVED} (survived, r=+1)  {STATE_DIED} (died, r=0)')
print(f'Fixed difficulty: sofa_bias={SOFA_BIAS}, lam={LAM}')
print(f'Config B: seeds={SEEDS_B}, total_steps={TOTAL_STEPS:,}, snapshot_every={SNAP_EVERY_B:,}')
print('Setup complete!')
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# ICU-Sepsis-v2 | States: 716 | Actions: 25
# Terminal states: 714 (survived, r=+1)  713 (died, r=0)
# Fixed difficulty: sofa_bias=5.0, lam=0.02
# Config B: seeds=[0, 1, 2], total_steps=150,000, snapshot_every=10,000
# Setup complete!

# %% [markdown]
# # <a class='anchor' id='explore-environment'></a>
# <div style="background: linear-gradient(to right, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C);
#             padding: 10px; color: white; text-align: center; max-width: 98%;">
#     <center><h1 style="margin-top: 10px; margin-bottom: 4px; color: white;
#                        font-size: 32px; font-family: 'Roboto', 'Segoe UI', sans-serif;">
#         <b>1. Explore the Environment</b></h1></center>
# </div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <h3 style="margin-top: 0; margin-bottom: 10px; color: #333333; font-weight: bold;">Understanding the MDP</h3>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Before any algorithm, understand the MDP. The insights gained here inform the report's Methodology section.</p>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;"><code>ICU-Sepsis-v2</code> is a benchmark MDP constructed from real MIMIC-III patient data. Each episode is the trajectory of one ICU patient. The agent observes a discrete integer state (0 to 715) and selects one of 25 treatment actions corresponding to combinations of vasopressor and IV-fluid dose levels. The reward is sparse: <strong>+1 at survival, 0 at death, and 0 for every intermediate step</strong>, with discount γ = 1.</p>
# </div>

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">Instantiate and inspect the raw environment</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;"><code>make_sepsis_env()</code> builds the discrete <code>ICU-Sepsis-v2</code> MDP and applies the fixed difficulty (<code>SOFA_BIAS = 5.0</code>, <code>LAM = 0.02</code>). We inspect its observation and action spaces, then extract the full transition and reward tensors <code>P</code> and <code>R</code> — Config A's defining affordance, which makes both Bellman backups and analytical policy evaluation possible later.</p>
# </div>

# %%
env = make_sepsis_env()
obs, info = env.reset(seed=SEED)

print(f'Observation space : {env.observation_space} discrete integer state')
print(f'Action space      : {env.action_space}')
print(f'Initial state     : {obs}')
print()

raw = env.unwrapped
P = raw._tx_mat
R_sasp = raw._r_mat
R = (P * R_sasp).sum(axis=2)

print(f'Transition matrix P : {P.shape}  (S × A × S\')')
print(f'Reward matrix R     : {R.shape}  (S × A)')
print(f'Reward range        : [{R.min():.3f}, {R.max():.3f}]')
print()
# Out:
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# Observation space : Discrete(716) discrete integer state
# Action space      : Discrete(25)
# Initial state     : 559
#
# Transition matrix P : (716, 25, 716)  (S × A × S')
# Reward matrix R     : (716, 25)  (S × A)
# Reward range        : [-0.020, 0.708]

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">Random baseline: the performance floor</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">A uniformly random policy gives the minimum bar any learned policy must clear. The same 1000-episode evaluation protocol is used throughout Config A so that every algorithm's numbers are directly comparable.</p>
# </div>

# %%
rand_returns, rand_lengths = run_random_baseline()
survival_rate = float(np.mean(rand_returns > 0)) * 100

print(f'Random agent ({len(rand_returns)} episodes):')
print(f'  Mean return    : {np.mean(rand_returns):.4f}')
print(f'  Survival rate  : {survival_rate:.1f}%')
print(f'  Mean ep length : {np.mean(rand_lengths):.1f} steps')
print()
print('All Config A algorithms must beat the random baseline.')
# Out:
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# Random agent (1000 episodes):
#   Mean return    : 0.5711
#   Survival rate  : 67.5%
#   Mean ep length : 10.4 steps
#
# All Config A algorithms must beat the random baseline.

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">State visitation and reward structure</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Two diagnostics about the MDP: which states the agent encounters under a random policy, and where the reward signal lives. Together they motivate the sparse-reward, short-horizon framing used by every Config A algorithm.</p>
# </div>

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

np.random.seed(SEED)
env_vis = make_sepsis_env()
env_vis.action_space.seed(SEED)
visited = []
for _ in range(300):
    obs, _ = env_vis.reset(seed=np.random.randint(100_000))
    done = False
    while not done:
        visited.append(int(obs))
        obs, _, te, tr, _ = env_vis.step(env_vis.action_space.sample())
        done = te or tr
env_vis.close()
clinical = [s for s in visited if s not in (STATE_SURVIVED, STATE_DIED)]

axes[0].hist(clinical, bins=60, color='steelblue', edgecolor='none', alpha=0.8)
axes[0].set_xlabel('State index (0–713 = clinical)')
axes[0].set_ylabel('Visit count')
axes[0].set_title('State visitation random policy (300 episodes)', fontweight='bold')

axes[1].bar(range(N_STATES), R.max(axis=1), color='tomato', width=1.0, alpha=0.8)
axes[1].set_xlabel('State index')
axes[1].set_ylabel('max_a R(s,a)')
axes[1].set_title('Reward sparsity only terminal transitions carry reward',
                  fontweight='bold')

plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/configA_env_exploration.png', bbox_inches='tight')
plt.show()
# Out:
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">The continuous (Config B) environment</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Config A used the discrete state index. Config B uses the same MDP but exposes the agent to the 47-dimensional continuous physiological vector (SOFA, heart rate, lactate, blood pressure, creatinine, and 42 more), wrapped in three orthogonal clinical-reality failure modes:</p>
#     <ul style="margin: 10px 40px 10px 20px; padding-left: 20px; padding-right: 0; color: #757575;">
#         <li style="margin-right: 20px;"><code>EpisodicNoisyObsEnv</code> — with probability 0.15 the whole episode's observations are corrupted by Gaussian noise (monitor malfunction).</li>
#         <li style="margin-right: 20px;"><code>EpisodicMissingObsEnv</code> — with probability 0.15 a fixed subset of features is zeroed for the whole episode (lab-analyser downtime or missing chart entries).</li>
#         <li style="margin-right: 20px;"><code>AcuteEventEnv</code> — at each step a small probability (0.01) of a sudden unrecoverable event that ends the episode in death regardless of treatment (irreducible stochasticity).</li>
#     </ul>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Below we inspect the spaces, define the single fixed evaluation function used by all Config B agents, and measure the random-policy floor with a breakdown over the three failure modes.</p>
#     <div style="background-color: #A8C5E0; padding: 10px; margin-top: 10px; margin-right: 30px; border-left: 5px solid #4682B4; border-radius: 5px; max-width: 95%; color: #333333;">
#         <strong>Important:</strong> <code>make_clinical_env()</code> composes all three wrappers and is the required environment for every Config B result.
#     </div>
# </div>

# %%
clinical_env = make_clinical_env()
obs0, info0 = clinical_env.reset(seed=SEED)
print('Observation space :', clinical_env.observation_space)
print('Action space      :', clinical_env.action_space)
print('Info keys         :', list(info0.keys()))
print('Sample obs (first 8 of 47):', np.round(obs0[:8], 3))

layer = clinical_env
stack_names = []
while hasattr(layer, 'env'):
    stack_names.append(type(layer).__name__)
    layer = layer.env
stack_names.append(type(layer).__name__)
print('Wrapper stack     :', ' -> '.join(stack_names))
clinical_env.close()
# Out:
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# Observation space : Box(-inf, inf, (47,), float32)
# Action space      : Discrete(25)
# Info keys         : ['admissible_actions', 'state_vector', 'sofa_score', 'noisy_episode', 'missing_features']
# Sample obs (first 8 of 47): [-0.052 -0.47  -0.5    0.428  0.504  0.097  0.282 -0.394]
# Wrapper stack     : AcuteEventEnv -> EpisodicMissingObsEnv -> EpisodicNoisyObsEnv -> ContinuousICUSepsisEnv

# %%
set_global_seeds(SEED)
clinical_rand_returns, clinical_rand_lengths, clinical_rand_info = evaluate_agent(random_predict, n_episodes=1000, seed=SEED)
clinical_rand_mean = float(clinical_rand_returns.mean())
clinical_rand_surv = float((clinical_rand_returns > 0).mean()) * 100

noisy_mask = clinical_rand_info['noisy']
missing_mask = clinical_rand_info['missing']
acute_mask = clinical_rand_info['acute']
survived = clinical_rand_returns > 0

group_labels = ['Overall', 'Clean obs', 'Noisy obs', 'Full labs', 'Missing labs', 'No acute', 'Acute event']
group_rates = [
    clinical_rand_surv,
    subset_survival(survived, ~noisy_mask),
    subset_survival(survived, noisy_mask),
    subset_survival(survived, ~missing_mask),
    subset_survival(survived, missing_mask),
    subset_survival(survived, ~acute_mask),
    subset_survival(survived, acute_mask),
]
group_colors = ['black', 'steelblue', 'tomato', 'steelblue', 'tomato', 'steelblue', 'tomato']

print('=== Random baseline on clinical env (1000 episodes) ===')
print(f'Mean return    : {clinical_rand_mean:.4f}')
print(f'Survival rate  : {clinical_rand_surv:.1f}%')
print(f'Mean ep length : {clinical_rand_lengths.mean():.1f} steps')
print(f'Noisy episodes : {noisy_mask.mean()*100:.1f}%  Missing: {missing_mask.mean()*100:.1f}%  Acute: {acute_mask.mean()*100:.1f}%')

fig, ax = plt.subplots(figsize=(11, 4.6))
x_pos = np.arange(len(group_labels))
bars = ax.bar(x_pos, group_rates, color=group_colors, alpha=0.8)
ax.set_xticks(x_pos)
ax.set_xticklabels(group_labels, rotation=20, ha='right')
ax.set_ylabel('Survival rate (%)')
ax.set_title('Random-policy survival by clinical failure mode (Config B floor)', fontweight='bold')
ax.grid(True, alpha=0.3, axis='y')

# Annotate each bar with its survival rate just above the bar top
for bar, rate in zip(bars, group_rates):
    bar_height = bar.get_height()
    label_x = bar.get_x() + bar.get_width() / 2
    label_text = f'{rate:.1f}%'
    ax.text(label_x, bar_height + 1, label_text, ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/configB_env_exploration.png', bbox_inches='tight')
plt.show()
# Out:
# === Random baseline on clinical env (1000 episodes) ===
# Mean return    : 0.5587
# Survival rate  : 65.0%
# Mean ep length : 9.2 steps
# Noisy episodes : 13.7%  Missing: 16.3%  Acute: 7.9%

# %% [markdown]
# # <a class='anchor' id='config-a-tabular'></a>
#
# <div style="background: linear-gradient(to right, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C);
#             padding: 10px; color: white; text-align: center; max-width: 98%;">
#     <center><h1 style="margin-top: 10px; margin-bottom: 4px; color: white;
#                        font-size: 32px; font-family: 'Roboto', 'Segoe UI', sans-serif;">
#         <b>2. Config A — Tabular Methods</b></h1></center>
# </div>
#
# <br>
#
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <h3 style="margin-top: 0; margin-bottom: 10px; color: #333333; font-weight: bold;">Why tabular methods</h3>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">With 716 discrete states and 25 actions, the Q-table has shape (716, 25) — 17,900 entries. That size is manageable in memory, which is exactly what motivates tabular algorithms here.</p>
# </div>

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">A.1 Value Iteration (model-based optimal reference)</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Config A exposes the full MDP (the transition tensor <code>P</code> and expected-reward matrix <code>R</code> extracted above), so the optimal policy can be computed directly. Value Iteration repeatedly applies the Bellman optimality backup, updating each state's value to the best one-step return achievable under the known model, and stops once the value function settles. Because it uses the true model, the resulting policy <code>pi_VI</code> is the optimal reference against which every model-free method in A.2 and A.3 is measured.</p>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">We evaluate <code>pi_VI</code> with the same 1000-episode protocol and fixed seeding as the random baseline, so its Monte-Carlo return is directly comparable to the other algorithms.</p>
# </div>

# %%
V = np.zeros(N_STATES)
vi_deltas = []
vi_policy_changes = []
pi_prev = -np.ones(N_STATES, dtype=int)
for it in range(1000):
    Q_sa = R + GAMMA * P.dot(V)
    V_new = Q_sa.max(axis=1)
    pi_k = Q_sa.argmax(axis=1)
    delta = float(np.max(np.abs(V_new - V)))
    if it == 0:
        n_changed = N_STATES
    else:
        policy_change_mask = pi_k != pi_prev
        n_changed = int(policy_change_mask.sum())
    vi_deltas.append(delta)
    vi_policy_changes.append(n_changed)
    pi_prev = pi_k
    V = V_new
    if delta < 1e-10:
        break

V_VI = V
Q_VI = Q_sa
pi_VI = pi_k
vi_iters = len(vi_deltas)

vi_returns, vi_lengths = evaluate_policy(pi_VI)
vi_survived = vi_returns > 0
vi_mean_ret = float(vi_returns.mean())
vi_surv = float(vi_survived.mean()) * 100
vi_mean_len = float(vi_lengths.mean())

rand_survived = rand_returns > 0
rand_mean = float(rand_returns.mean())
rand_surv = float(rand_survived.mean()) * 100

print(f'Value Iteration converged in {vi_iters} iterations (final Δ = {vi_deltas[-1]:.2e})')
print(f'Mean return    : {vi_mean_ret:.4f}    (random baseline: {rand_mean:.4f})')
print(f'Survival rate  : {vi_surv:.1f}%        (random baseline: {rand_surv:.1f}%)')
print(f'Mean ep length : {vi_mean_len:.1f} steps')
# Out:
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# Value Iteration converged in 237 iterations (final Δ = 9.77e-11)
# Mean return    : 0.7507    (random baseline: 0.5711)
# Survival rate  : 78.8%        (random baseline: 67.5%)
# Mean ep length : 9.8 steps

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">Convergence diagnostics</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Two views of how Value Iteration converges. The Bellman-residual panel (log scale) tracks the largest change in any state's value between iterations, decaying geometrically toward the 1e-10 tolerance. The policy-stability panel counts how many states change their greedy action each iteration. The policy usually locks in long before the value function fully converges, so the final iterations are numerical polish with no effect on the decisions made.</p>
# </div>

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))

iters_axis = np.arange(1, vi_iters + 1)
vi_deltas_arr = np.array(vi_deltas)
vi_policy_changes_arr = np.array(vi_policy_changes)

post_init_zero_mask = vi_policy_changes_arr[1:] == 0
if post_init_zero_mask.any():
    first_zero_slice_idx = int(np.argmax(post_init_zero_mask))
    iter_policy_stable = first_zero_slice_idx + 2
else:
    iter_policy_stable = vi_iters

axes[0].semilogy(iters_axis, vi_deltas_arr, color='darkgreen', linewidth=1.8)
axes[0].axhline(1e-10, color='gray', linestyle='--', linewidth=1.0,
                label='Convergence threshold (1e-10)')
axes[0].axvline(vi_iters, color='tomato', linestyle=':', linewidth=1.2,
                label=f'Converged at iter {vi_iters}')
axes[0].set_xlabel('Iteration')
axes[0].set_ylabel(r'$\|V_{k+1} - V_k\|_\infty$  (log scale)')
axes[0].set_title('Bellman residual', fontweight='bold')
axes[0].legend(loc='upper right')
axes[0].grid(True, which='both', alpha=0.3)

policy_panel_title = f'Policy stable at iter {iter_policy_stable} < value convergence at {vi_iters}'
axes[1].plot(iters_axis, vi_policy_changes_arr, color='tomato', linewidth=1.8)
axes[1].axvline(iter_policy_stable, color='gray', linestyle=':', linewidth=1.2,
                label=f'Stable at iter {iter_policy_stable}')
axes[1].set_xlabel('Iteration')
axes[1].set_ylabel('# states with policy change')
axes[1].set_title(policy_panel_title, fontweight='bold')
axes[1].legend(loc='upper right')
axes[1].grid(True, alpha=0.3)

fig.suptitle('Value Iteration convergence — Config A', fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/configA_vi_convergence.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">Exact policy evaluation via linear solve</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Because the MDP is known, the expected return of any policy can be computed exactly without rollouts by solving a small linear system for the policy's value function over the non-terminal states. The Monte-Carlo estimates are kept too (for the return-distribution plot and as a simulator-versus-model sanity check), but this analytical return is the precise number used for the optimality-gap comparison.</p>
#     <div style="background-color: #A8C5E0; padding: 10px; margin-top: 10px; margin-right: 30px; border-left: 5px solid #4682B4; border-radius: 5px; max-width: 95%; color: #333333;">
#         <strong>Note:</strong> The gym wrapper ends an episode on reaching state 713 (died) or 714 (survived), but in the underlying MDP both transition onward into 715, the only true absorbing state. The linear solve therefore uses the structural absorber set (detected via self-loop probability): treating 713 and 714 as terminal would make the system singular for the random policy.
#     </div>
# </div>

# %%
all_states = np.arange(N_STATES)
self_loop_prob = np.zeros((N_STATES, N_ACTIONS))
for s in all_states:
    self_loop_prob[s, :] = P[s, :, s]
is_absorbing_per_action = self_loop_prob == 1.0
is_absorbing = is_absorbing_per_action.all(axis=1)
NON_TERMINAL = all_states[~is_absorbing]


def analytical_J(policy=None):
    """Exact expected return d_0 · V_π.

    policy: deterministic policy (N_STATES,) action array, or None for the
        uniform-random policy.
    Returns (J, V_π) with V_π zero on terminal states.
    """
    if policy is None:
        P_pi = P.mean(axis=1)
        R_pi = R.mean(axis=1)
    else:
        state_idx = np.arange(N_STATES)
        P_pi = P[state_idx, policy, :]
        R_pi = R[state_idx, policy]

    P_nt = P_pi[np.ix_(NON_TERMINAL, NON_TERMINAL)]
    R_nt = R_pi[NON_TERMINAL]
    A_mat = np.eye(len(NON_TERMINAL)) - GAMMA * P_nt

    V_pi = np.zeros(N_STATES)
    V_pi[NON_TERMINAL] = np.linalg.solve(A_mat, R_nt)
    J = float(raw._d_0 @ V_pi)
    out = (J, V_pi)
    return out


J_rand_exact, _ = analytical_J(policy=None)
J_VI_exact, V_VI_exact = analytical_J(pi_VI)


mc_vs_analytical_gap = abs(vi_mean_ret - J_VI_exact)

print('Analytical J (exact, no sampling):')
print(f'  Random policy       : {J_rand_exact:.4f}')
print(f'  VI policy           : {J_VI_exact:.4f}')
print(f'  MC mean (1000, VI)  : {vi_mean_ret:.4f}   → simulator-model gap {mc_vs_analytical_gap:.4f}')
# Out:
# Analytical J (exact, no sampling):
#   Random policy       : 0.6053
#   VI policy           : 0.7853
#   MC mean (1000, VI)  : 0.7507   → simulator-model gap 0.0346

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">A.2 Q-Learning (model-free)</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Q-Learning is the model-free TD(0) counterpart to the Value Iteration cell above. Including it despite having <code>P</code> and <code>R</code> validates that an agent without access to the MDP model can recover essentially the same policy by interacting with the simulator. We train across 3 seeds so the learning curve can show mean ± std, and pick the median seed for downstream policy visualisations.</p>
# </div>

# %%
N_EPISODES = 200_000
ALPHA = 0.1
EPS_START = 1.0
EPS_END = 0.05
EPS_DECAY_END = int(0.8 * N_EPISODES)
SEEDS = [0, 1, 2]
SNAPSHOT_EVERY = 5_000

ql_eps_schedule = np.empty(N_EPISODES)
for ep in range(N_EPISODES):
    frac = min(ep / EPS_DECAY_END, 1.0)
    ql_eps_schedule[ep] = EPS_START + (EPS_END - EPS_START) * frac

snapshot_eps_list = list(range(SNAPSHOT_EVERY, N_EPISODES + 1, SNAPSHOT_EVERY))
if snapshot_eps_list[-1] != N_EPISODES:
    snapshot_eps_list.append(N_EPISODES)
snapshot_eps = np.array(snapshot_eps_list)

Q_QL_per_seed = []
ql_curves = np.empty((len(SEEDS), N_EPISODES))
ql_lengths_train = np.empty((len(SEEDS), N_EPISODES))
ql_td_errors = np.empty((len(SEEDS), N_EPISODES))
ql_snapshots_per_seed = []

for s_idx, seed in enumerate(SEEDS):
    env_train = make_sepsis_env()
    env_train.action_space.seed(seed)
    rng = np.random.default_rng(seed)
    Q = np.zeros((N_STATES, N_ACTIONS))
    seed_snapshots = []

    for ep in range(N_EPISODES):
        eps = ql_eps_schedule[ep]
        obs, _ = env_train.reset(seed=int(rng.integers(0, 100_000)))
        total_r = 0.0
        steps = 0
        abs_td_sum = 0.0
        done = False
        while not done:
            if rng.random() < eps:
                action = int(env_train.action_space.sample())
            else:
                action = int(Q[obs].argmax())
            next_obs, r, te, tr, _ = env_train.step(action)
            terminal = te or tr
            if terminal:
                target = r
            else:
                target = r + GAMMA * Q[next_obs].max()
            td_error = target - Q[obs, action]
            Q[obs, action] += ALPHA * td_error
            abs_td_sum += abs(td_error)
            total_r += r
            steps += 1
            obs = next_obs
            done = terminal

        ql_curves[s_idx, ep] = total_r
        ql_lengths_train[s_idx, ep] = steps
        ql_td_errors[s_idx, ep] = abs_td_sum / max(steps, 1)

        if (ep + 1) in snapshot_eps_list:
            seed_snapshots.append(Q.copy())

    env_train.close()
    Q_QL_per_seed.append(Q)
    ql_snapshots_per_seed.append(seed_snapshots)

ql_returns_per_seed = []
ql_lengths_per_seed = []
for Q in Q_QL_per_seed:
    pi_seed = Q.argmax(axis=1)
    seed_returns, seed_lengths = evaluate_policy(pi_seed)
    ql_returns_per_seed.append(seed_returns)
    ql_lengths_per_seed.append(seed_lengths)

seed_means_list = []
seed_survs_list = []
seed_lens_list = []
for r_arr, l_arr in zip(ql_returns_per_seed, ql_lengths_per_seed):
    seed_means_list.append(r_arr.mean())
    survival_pct = float((r_arr > 0).mean()) * 100
    seed_survs_list.append(survival_pct)
    seed_lens_list.append(l_arr.mean())
ql_means = np.array(seed_means_list)
ql_survs = np.array(seed_survs_list)
ql_lens = np.array(seed_lens_list)

median_value = float(np.median(ql_means))
distances = np.abs(ql_means - median_value)
median_seed_idx = int(distances.argmin())
Q_QL = Q_QL_per_seed[median_seed_idx]
pi_QL = Q_QL.argmax(axis=1)

ql_pooled_returns = np.concatenate(ql_returns_per_seed)
ql_pooled_lengths = np.concatenate(ql_lengths_per_seed)
ql_mean_ret = float(ql_pooled_returns.mean())
ql_surv = float((ql_pooled_returns > 0).mean()) * 100
ql_mean_len = float(ql_pooled_lengths.mean())

print(f'Q-Learning trained for {N_EPISODES} episodes × {len(SEEDS)} seeds (α={ALPHA}, ε: {EPS_START}→{EPS_END})')
print(f'  Per-seed mean return   : {np.array2string(ql_means, precision=4)}')
print(f'  Per-seed survival rate : {np.array2string(ql_survs, precision=1)}%')
print(f'  Pooled mean return     : {ql_mean_ret:.4f}    (VI: {vi_mean_ret:.4f}, random: {rand_mean:.4f})')
print(f'  Pooled survival rate   : {ql_surv:.1f}%        (VI: {vi_surv:.1f}%, random: {rand_surv:.1f}%)')
print(f'  Pooled mean ep length  : {ql_mean_len:.1f} steps')
print(f'  Median seed for policy viz : seed={SEEDS[median_seed_idx]} (mean eval return {ql_means[median_seed_idx]:.4f})')
print(f'  Snapshots per seed     : {len(snapshot_eps)} (every {SNAPSHOT_EVERY} episodes)')
# Out:
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# Q-Learning trained for 200000 episodes × 3 seeds (α=0.1, ε: 1.0→0.05)
#   Per-seed mean return   : [0.6746 0.6633 0.674 ]
#   Per-seed survival rate : [76.5 75.1 76.8]%
#   Pooled mean return     : 0.6706    (VI: 0.7507, random: 0.5711)
#   Pooled survival rate   : 76.1%        (VI: 78.8%, random: 67.5%)
# ...

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">Q-Learning learning curve</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Rolling-500-episode mean return averaged across seeds with a ±1 std band, and the ε schedule overlaid on a twin axis. The horizontal dashed line marks the Value Iteration ceiling.</p>
# </div>

# %%
WINDOW = 500

rolling_per_seed = []
for s_idx in range(len(SEEDS)):
    seed_curve = ql_curves[s_idx]
    seed_rolling = rolling_mean(seed_curve, WINDOW)
    rolling_per_seed.append(seed_rolling)
rolling_stack = np.vstack(rolling_per_seed)
rolling_mean_across_seeds = rolling_stack.mean(axis=0)
rolling_std_across_seeds = rolling_stack.std(axis=0)
x_axis = np.arange(WINDOW - 1, N_EPISODES)

fig, ax1 = plt.subplots(figsize=(12, 5))

ax1.plot(x_axis, rolling_mean_across_seeds, color='steelblue', linewidth=2.0,
         label=f'Q-Learning mean across {len(SEEDS)} seeds (rolling-{WINDOW})')
upper_band = rolling_mean_across_seeds + rolling_std_across_seeds
lower_band = rolling_mean_across_seeds - rolling_std_across_seeds
ax1.fill_between(x_axis, lower_band, upper_band, color='steelblue', alpha=0.2,
                 label='±1 std across seeds')

ax1.axhline(vi_mean_ret, color='darkgreen', linestyle='--', linewidth=1.5,
            label=f'Value Iteration ({vi_mean_ret:.3f})')
ax1.axhline(rand_mean, color='gray', linestyle=':', linewidth=1.5,
            label=f'Random baseline ({rand_mean:.3f})')

ax1.set_xlabel('Training episode')
ax1.set_ylabel('Episode return (rolling mean)')
ax1.set_title('Q-Learning learning curve — Config A', fontweight='bold')
ax1.legend(loc='lower right')
ax1.grid(True, alpha=0.3)

ax2 = ax1.twinx()
ax2.plot(np.arange(N_EPISODES), ql_eps_schedule, color='tomato', linewidth=1.2,
         alpha=0.7, label='ε (exploration rate)')
ax2.set_ylabel('ε', color='tomato')
ax2.tick_params(axis='y', labelcolor='tomato')
ax2.set_ylim(0, 1.05)
ax2.legend(loc='upper right')

plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/configA_qlearning_curve.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">A.3 SARSA (on-policy TD)</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">SARSA is the on-policy counterpart to Q-Learning. They differ in a single line of the update: Q-Learning bootstraps from max over a' of Q(s', a') (the value of the greedy next action), while SARSA bootstraps from Q(s', a') for the action a' actually sampled under the current ε-greedy policy.</p>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">This distinction matters in a clinical-safety frame. Q-Learning learns the value of a deterministic optimum as if the agent will never explore again; SARSA learns the value of the policy the agent actually executes, including its ε-greedy exploratory moves. When exploration steps can hurt patients, SARSA's risk-aware estimate tends to favour policies whose neighbourhood under exploration is also acceptable.</p>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">We mirror the Q-Learning setup exactly (200k episodes × 3 seeds, α = 0.1, ε decay 1.0 → 0.05 over 80% of training, identical 1000-episode evaluation set) so the two algorithms are directly comparable in the A.4 table and the optimality-gap plot.</p>
# </div>

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">SARSA training across 3 seeds</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Same hyperparameters and ε schedule as Q-Learning; the only change is the bootstrap target. Q-snapshots are captured here for the optimality-gap analysis.</p>
# </div>

# %%
Q_SARSA_per_seed = []
sarsa_curves = np.empty((len(SEEDS), N_EPISODES))
sarsa_lengths_train = np.empty((len(SEEDS), N_EPISODES))
sarsa_td_errors = np.empty((len(SEEDS), N_EPISODES))
sarsa_snapshots_per_seed = []


def eps_greedy_action(Q_row, eps_val, n_actions, rng_local, env_local):
    if rng_local.random() < eps_val:
        out = int(env_local.action_space.sample())
    else:
        out = int(Q_row.argmax())
    return out


for s_idx, seed in enumerate(SEEDS):
    env_train = make_sepsis_env()
    env_train.action_space.seed(seed)
    rng = np.random.default_rng(seed)
    Q = np.zeros((N_STATES, N_ACTIONS))
    seed_snapshots = []

    for ep in range(N_EPISODES):
        eps = ql_eps_schedule[ep]
        obs, _ = env_train.reset(seed=int(rng.integers(0, 100_000)))
        action = eps_greedy_action(Q[obs], eps, N_ACTIONS, rng, env_train)
        total_r = 0.0
        steps = 0
        abs_td_sum = 0.0
        done = False
        while not done:
            next_obs, r, te, tr, _ = env_train.step(action)
            terminal = te or tr
            if terminal:
                target = r
                next_action = 0
            else:
                next_action = eps_greedy_action(Q[next_obs], eps, N_ACTIONS, rng, env_train)
                target = r + GAMMA * Q[next_obs, next_action]
            td_error = target - Q[obs, action]
            Q[obs, action] += ALPHA * td_error
            abs_td_sum += abs(td_error)
            total_r += r
            steps += 1
            obs = next_obs
            action = next_action
            done = terminal

        sarsa_curves[s_idx, ep] = total_r
        sarsa_lengths_train[s_idx, ep] = steps
        sarsa_td_errors[s_idx, ep] = abs_td_sum / max(steps, 1)

        if (ep + 1) in snapshot_eps_list:
            seed_snapshots.append(Q.copy())

    env_train.close()
    Q_SARSA_per_seed.append(Q)
    sarsa_snapshots_per_seed.append(seed_snapshots)

sarsa_returns_per_seed = []
sarsa_lengths_per_seed = []
for Q in Q_SARSA_per_seed:
    pi_seed = Q.argmax(axis=1)
    seed_returns, seed_lengths = evaluate_policy(pi_seed)
    sarsa_returns_per_seed.append(seed_returns)
    sarsa_lengths_per_seed.append(seed_lengths)

sarsa_seed_means_list = []
sarsa_seed_survs_list = []
sarsa_seed_lens_list = []
for r_arr, l_arr in zip(sarsa_returns_per_seed, sarsa_lengths_per_seed):
    sarsa_seed_means_list.append(r_arr.mean())
    survival_pct = float((r_arr > 0).mean()) * 100
    sarsa_seed_survs_list.append(survival_pct)
    sarsa_seed_lens_list.append(l_arr.mean())
sarsa_means = np.array(sarsa_seed_means_list)
sarsa_survs = np.array(sarsa_seed_survs_list)
sarsa_lens = np.array(sarsa_seed_lens_list)

sarsa_median_value = float(np.median(sarsa_means))
sarsa_distances = np.abs(sarsa_means - sarsa_median_value)
sarsa_median_seed_idx = int(sarsa_distances.argmin())
Q_SARSA = Q_SARSA_per_seed[sarsa_median_seed_idx]
pi_SARSA = Q_SARSA.argmax(axis=1)

sarsa_pooled_returns = np.concatenate(sarsa_returns_per_seed)
sarsa_pooled_lengths = np.concatenate(sarsa_lengths_per_seed)
sarsa_mean_ret = float(sarsa_pooled_returns.mean())
sarsa_surv = float((sarsa_pooled_returns > 0).mean()) * 100
sarsa_mean_len = float(sarsa_pooled_lengths.mean())

print(f'SARSA trained for {N_EPISODES} episodes × {len(SEEDS)} seeds (α={ALPHA}, ε: {EPS_START}→{EPS_END})')
print(f'  Per-seed mean return   : {np.array2string(sarsa_means, precision=4)}')
print(f'  Per-seed survival rate : {np.array2string(sarsa_survs, precision=1)}%')
print(f'  Pooled mean return     : {sarsa_mean_ret:.4f}    (QL: {ql_mean_ret:.4f}, VI: {vi_mean_ret:.4f})')
print(f'  Pooled survival rate   : {sarsa_surv:.1f}%        (QL: {ql_surv:.1f}%, VI: {vi_surv:.1f}%)')
print(f'  Pooled mean ep length  : {sarsa_mean_len:.1f} steps')
print(f'  Median seed for policy viz : seed={SEEDS[sarsa_median_seed_idx]} (mean eval return {sarsa_means[sarsa_median_seed_idx]:.4f})')
# Out:
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# SARSA trained for 200000 episodes × 3 seeds (α=0.1, ε: 1.0→0.05)
#   Per-seed mean return   : [0.6805 0.6584 0.6707]
#   Per-seed survival rate : [75.2 73.6 74.1]%
#   Pooled mean return     : 0.6699    (QL: 0.6706, VI: 0.7507)
#   Pooled survival rate   : 74.3%        (QL: 76.1%, VI: 78.8%)
# ...

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">SARSA learning curve</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Same rolling-mean across-seeds presentation as the Q-Learning curve, for direct visual comparison.</p>
# </div>

# %%
sarsa_rolling_per_seed = []
for s_idx in range(len(SEEDS)):
    seed_rolling = rolling_mean(sarsa_curves[s_idx], WINDOW)
    sarsa_rolling_per_seed.append(seed_rolling)
sarsa_rolling_stack = np.vstack(sarsa_rolling_per_seed)
sarsa_rolling_mean_across_seeds = sarsa_rolling_stack.mean(axis=0)
sarsa_rolling_std_across_seeds = sarsa_rolling_stack.std(axis=0)

fig, ax1 = plt.subplots(figsize=(12, 5))

ax1.plot(x_axis, sarsa_rolling_mean_across_seeds, color='darkorange', linewidth=2.0,
         label=f'SARSA mean across {len(SEEDS)} seeds (rolling-{WINDOW})')
sarsa_upper = sarsa_rolling_mean_across_seeds + sarsa_rolling_std_across_seeds
sarsa_lower = sarsa_rolling_mean_across_seeds - sarsa_rolling_std_across_seeds
ax1.fill_between(x_axis, sarsa_lower, sarsa_upper, color='darkorange', alpha=0.2,
                 label='±1 std across seeds')


ax1.axhline(vi_mean_ret, color='darkgreen', linestyle='--', linewidth=1.5,
            label=f'Value Iteration ({vi_mean_ret:.3f})')
ax1.axhline(rand_mean, color='gray', linestyle=':', linewidth=1.5,
            label=f'Random baseline ({rand_mean:.3f})')

ax1.set_xlabel('Training episode')
ax1.set_ylabel('Episode return (rolling mean)')
ax1.set_title('SARSA learning curve — Config A', fontweight='bold')
ax1.legend(loc='lower right')
ax1.grid(True, alpha=0.3)

ax2 = ax1.twinx()
ax2.plot(np.arange(N_EPISODES), ql_eps_schedule, color='tomato', linewidth=1.2,
         alpha=0.7, label='ε (exploration rate)')
ax2.set_ylabel('ε', color='tomato')
ax2.tick_params(axis='y', labelcolor='tomato')
ax2.set_ylim(0, 1.05)
ax2.legend(loc='upper right')

plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/configA_sarsa_curve.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">A.4 Algorithm comparison</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">We bring the four agents together: the random floor, the two model-free learners (Q-Learning, SARSA), and the model-based Value Iteration ceiling. The table reports mean return, survival rate with a bootstrap CI, mean episode length, and the exact analytical return J(π). The plots that follow show the full return distributions and how quickly each learner closes the gap to the VI optimum.</p>
# </div>

# %%
rand_return_mean = float(rand_returns.mean())
rand_return_std = float(rand_returns.std())
rand_survival = float((rand_returns > 0).mean()) * 100
rand_surv_lo, rand_surv_hi = bootstrap_survival_ci(rand_returns)
rand_length_mean = float(rand_lengths.mean())

ql_return_std = float(ql_pooled_returns.std())
ql_surv_lo, ql_surv_hi = bootstrap_survival_ci(ql_pooled_returns)

sarsa_return_std = float(sarsa_pooled_returns.std())
sarsa_surv_lo, sarsa_surv_hi = bootstrap_survival_ci(sarsa_pooled_returns)

vi_return_std = float(vi_returns.std())
vi_surv_lo, vi_surv_hi = bootstrap_survival_ci(vi_returns)

ql_J_values = []
for Q_seed in Q_QL_per_seed:
    pi_seed = Q_seed.argmax(axis=1)
    J_seed, _ = analytical_J(pi_seed)
    ql_J_values.append(J_seed)
ql_J_per_seed = np.array(ql_J_values)
ql_J_mean = float(ql_J_per_seed.mean())
ql_J_std = float(ql_J_per_seed.std())

sarsa_J_values = []
for Q_seed in Q_SARSA_per_seed:
    pi_seed = Q_seed.argmax(axis=1)
    J_seed, _ = analytical_J(pi_seed)
    sarsa_J_values.append(J_seed)
sarsa_J_per_seed = np.array(sarsa_J_values)
sarsa_J_mean = float(sarsa_J_per_seed.mean())
sarsa_J_std = float(sarsa_J_per_seed.std())

random_J_str = f'{J_rand_exact:.4f}'
ql_J_str = f'{ql_J_mean:.4f} ± {ql_J_std:.4f}'
sarsa_J_str = f'{sarsa_J_mean:.4f} ± {sarsa_J_std:.4f}'
vi_J_str = f'{J_VI_exact:.4f}'
analytical_col = [random_J_str, ql_J_str, sarsa_J_str, vi_J_str]

ql_delta_return = ql_mean_ret - rand_return_mean
ql_delta_surv = ql_surv - rand_survival
sarsa_delta_return = sarsa_mean_ret - rand_return_mean
sarsa_delta_surv = sarsa_surv - rand_survival
vi_delta_return = vi_mean_ret - rand_return_mean
vi_delta_surv = vi_surv - rand_survival

random_return_str = f'{rand_return_mean:.4f} ± {rand_return_std:.4f}'
ql_return_str = f'{ql_mean_ret:.4f} ± {ql_return_std:.4f}'
sarsa_return_str = f'{sarsa_mean_ret:.4f} ± {sarsa_return_std:.4f}'
vi_return_str = f'{vi_mean_ret:.4f} ± {vi_return_std:.4f}'

random_surv_str = f'{rand_survival:.1f}% [{rand_surv_lo:.1f}, {rand_surv_hi:.1f}]'
ql_surv_str = f'{ql_surv:.1f}% [{ql_surv_lo:.1f}, {ql_surv_hi:.1f}]'
sarsa_surv_str = f'{sarsa_surv:.1f}% [{sarsa_surv_lo:.1f}, {sarsa_surv_hi:.1f}]'
vi_surv_str = f'{vi_surv:.1f}% [{vi_surv_lo:.1f}, {vi_surv_hi:.1f}]'

ql_convergence_str = f'{N_EPISODES:,} eps × {len(SEEDS)} seeds'
sarsa_convergence_str = f'{N_EPISODES:,} eps × {len(SEEDS)} seeds'
vi_convergence_str = f'{vi_iters} iters (Δ<1e-10)'

ql_delta_return_str = f'{ql_delta_return:+.4f}'
ql_delta_surv_str = f'{ql_delta_surv:+.1f} pp'
sarsa_delta_return_str = f'{sarsa_delta_return:+.4f}'
sarsa_delta_surv_str = f'{sarsa_delta_surv:+.1f} pp'
vi_delta_return_str = f'{vi_delta_return:+.4f}'
vi_delta_surv_str = f'{vi_delta_surv:+.1f} pp'

algorithm_col = ['Random', 'Q-Learning', 'SARSA', 'Value Iteration']
return_col = [random_return_str, ql_return_str, sarsa_return_str, vi_return_str]
survival_col = [random_surv_str, ql_surv_str, sarsa_surv_str, vi_surv_str]
length_col = [f'{rand_length_mean:.1f}', f'{ql_mean_len:.1f}', f'{sarsa_mean_len:.1f}', f'{vi_mean_len:.1f}']
convergence_col = ['—', ql_convergence_str, sarsa_convergence_str, vi_convergence_str]
delta_return_col = ['—', ql_delta_return_str, sarsa_delta_return_str, vi_delta_return_str]
delta_surv_col = ['—', ql_delta_surv_str, sarsa_delta_surv_str, vi_delta_surv_str]

results_df = pd.DataFrame({
    'Algorithm': algorithm_col,
    'Analytical J (exact)': analytical_col,
    'Mean return ± std': return_col,
    'Survival % [95% CI]': survival_col,
    'Mean ep length': length_col,
    'Convergence': convergence_col,
    'Δ return vs random': delta_return_col,
    'Δ survival vs random': delta_surv_col,
})

display(results_df)
# Out:
#          Algorithm Analytical J (exact) Mean return ± std Survival % [95% CI]  \
# 0           Random               0.6053   0.5711 ± 0.4644  67.5% [64.6, 70.2]
# 1       Q-Learning      0.6888 ± 0.0048   0.6706 ± 0.4252  76.1% [74.5, 77.7]
# 2            SARSA      0.6889 ± 0.0027   0.6699 ± 0.4358  74.3% [72.9, 75.9]
# 3  Value Iteration               0.7853   0.7507 ± 0.4043  78.8% [76.4, 81.5]
#
#   Mean ep length            Convergence Δ return vs random  \
# 0           10.4                      —                  —
# 1           11.0  200,000 eps × 3 seeds            +0.0996
# 2            9.6  200,000 eps × 3 seeds            +0.0988
# 3            9.8    237 iters (Δ<1e-10)            +0.1796
#
#   Δ survival vs random
# 0                    —
# 1              +8.6 pp
# 2              +6.8 pp
# 3             +11.3 pp

# %%
fig, ax = plt.subplots(figsize=(11, 5))

dataset = [rand_returns, ql_pooled_returns, sarsa_pooled_returns, vi_returns]
labels = ['Random',
          f'Q-Learning\n(pooled, {len(SEEDS)} seeds)',
          f'SARSA\n(pooled, {len(SEEDS)} seeds)',
          'Value Iteration']
colors = ['gray', 'steelblue', 'darkorange', 'darkgreen']

parts = ax.violinplot(dataset, showmeans=False, showmedians=False, showextrema=False,
                     widths=0.85)
for body, color in zip(parts['bodies'], colors):
    body.set_facecolor(color)
    body.set_alpha(0.45)
    body.set_edgecolor('black')

positions = np.arange(1, len(dataset) + 1)
means = []
survivals = []
for arr in dataset:
    means.append(float(arr.mean()))
    surv_pct = float((arr > 0).mean()) * 100
    survivals.append(surv_pct)
ax.scatter(positions, means, color='black', s=60, zorder=3, label='Mean return')

for x, m, s in zip(positions, means, survivals):
    annotation_text = f'μ={m:.3f}\nsurv={s:.1f}%'
    ax.annotate(annotation_text, xy=(x, m), xytext=(x + 0.15, m),
                fontsize=9, va='center')

ax.set_xticks(positions)
ax.set_xticklabels(labels)
ax.set_ylabel('Episode return')
ax.set_title('Evaluation return distributions — Config A (1000 episodes each)',
             fontweight='bold')
ax.legend(loc='lower right')
ax.grid(True, axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/configA_return_distribution.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <h3 style="margin-top: 0; margin-bottom: 10px; color: #333333; font-weight: bold;">Main Takeaways</h3>
#     <ul style="margin: 10px 40px 10px 20px; padding-left: 20px; padding-right: 0; color: #757575;">
#         <li style="margin-right: 20px;">Returns are near-bimodal: a death lobe near 0 (minus the accrued intensity penalty) and a survival lobe near +1.</li>
#         <li style="margin-right: 20px;">Random sits lowest; Q-Learning and SARSA shift mass into the survival lobe.</li>
#         <li style="margin-right: 20px;">Q-Learning and SARSA land close to each other and to the Value-Iteration reference.</li>
#     </ul>
#     <h3 style="margin-top: 18px; margin-bottom: 10px; color: #333333; font-weight: bold;">Interpretation</h3>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">The violin exposes how each agent's probability mass splits between death and survival; the mean alone hides this. The close clustering of Q-Learning, SARSA, and VI is the visual counterpart of their near-identical survival numbers in the table above.</p>
# </div>

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">Optimality gap during training</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">For each Q-table snapshot taken during training we derive the greedy policy and compute its exact analytical return J(πₜ) via the linear solve from A.1. Plotting J(πₜ)/J(π_VI) over episodes shows how quickly each model-free method approaches the model-based optimum. The dashed line at 1.0 is the Value Iteration ceiling.</p>
# </div>

# %%
def snapshots_to_J(snapshots_per_seed):
    n_seeds = len(snapshots_per_seed)
    n_snaps = len(snapshots_per_seed[0])
    J_arr = np.empty((n_seeds, n_snaps))
    for s_i, seed_snaps in enumerate(snapshots_per_seed):
        for k, Q_snap in enumerate(seed_snaps):
            pi_snap = Q_snap.argmax(axis=1)
            J_val, _ = analytical_J(pi_snap)
            J_arr[s_i, k] = J_val
    return J_arr


ql_J_traj = snapshots_to_J(ql_snapshots_per_seed)
sarsa_J_traj = snapshots_to_J(sarsa_snapshots_per_seed)

ql_gap = ql_J_traj / J_VI_exact
sarsa_gap = sarsa_J_traj / J_VI_exact

ql_gap_mean = ql_gap.mean(axis=0)
ql_gap_std = ql_gap.std(axis=0)
sarsa_gap_mean = sarsa_gap.mean(axis=0)
sarsa_gap_std = sarsa_gap.std(axis=0)

fig, ax = plt.subplots(figsize=(11, 5))

ax.plot(snapshot_eps, ql_gap_mean, color='steelblue', linewidth=2.0, marker='o',
        markersize=4, label='Q-Learning (mean across seeds)')
ax.fill_between(snapshot_eps, ql_gap_mean - ql_gap_std, ql_gap_mean + ql_gap_std,
                color='steelblue', alpha=0.2, label='Q-Learning ±1 std')

ax.plot(snapshot_eps, sarsa_gap_mean, color='darkorange', linewidth=2.0, marker='s',
        markersize=4, label='SARSA (mean across seeds)')
ax.fill_between(snapshot_eps, sarsa_gap_mean - sarsa_gap_std, sarsa_gap_mean + sarsa_gap_std,
                color='darkorange', alpha=0.2, label='SARSA ±1 std')

ax.axhline(1.0, color='darkgreen', linestyle='--', linewidth=1.5,
           label='Value Iteration optimum (J = 1.000)')

random_ratio = J_rand_exact / J_VI_exact
ax.axhline(random_ratio, color='gray', linestyle=':', linewidth=1.2,
           label=f'Random policy ratio ({random_ratio:.3f})')

ax.set_xlabel('Training episode')
ax.set_ylabel(r'Optimality ratio  $J(\pi_t) / J(\pi_{VI})$')
ax.set_title('Optimality gap during training — Config A', fontweight='bold')
ax.set_ylim(min(random_ratio - 0.05, 0.5), 1.05)
ax.legend(loc='lower right', fontsize=9)
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/configA_optimality_gap.png', bbox_inches='tight')
plt.show()

print('Final optimality ratio (mean ± std across seeds):')
print(f'  Q-Learning : {ql_gap_mean[-1]:.4f} ± {ql_gap_std[-1]:.4f}')
print(f'  SARSA      : {sarsa_gap_mean[-1]:.4f} ± {sarsa_gap_std[-1]:.4f}')
# Out:
# Final optimality ratio (mean ± std across seeds):
#   Q-Learning : 0.8771 ± 0.0061
#   SARSA      : 0.8772 ± 0.0034

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <h3 style="margin-top: 0; margin-bottom: 10px; color: #333333; font-weight: bold;">Main Takeaways</h3>
#     <ul style="margin: 10px 40px 10px 20px; padding-left: 20px; padding-right: 0; color: #757575;">
#         <li style="margin-right: 20px;">The ratio J(πₜ)/J(π_VI) uses each policy's exact return from the A.1 linear solve, not noisy rollouts.</li>
#         <li style="margin-right: 20px;">Both the Q-Learning and SARSA curves climb steeply early, then flatten just below 1.0.</li>
#         <li style="margin-right: 20px;">A small residual gap remains, from the constant step size α and the ε-floor.</li>
#     </ul>
#     <h3 style="margin-top: 18px; margin-bottom: 10px; color: #333333; font-weight: bold;">Interpretation</h3>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">The exact-return ratio measures how fast each model-free learner approaches the model-based optimum. The residual gap below 1.0 is expected for constant-α TD with a non-zero exploration floor.</p>
# </div>

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">A.5 Policy interpretation</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Survival numbers tell us how well a policy does; this section asks what it actually does and whether that makes clinical sense. Three complementary views:</p>
#     <ul style="margin: 10px 40px 10px 20px; padding-left: 20px; padding-right: 0; color: #757575;">
#         <li style="margin-right: 20px;"><strong>What treatment intensity does the policy choose?</strong> (action heatmaps) — does it lean on aggressive vasopressor/fluid combinations, or stay parsimonious as the λ penalty intends?</li>
#         <li style="margin-right: 20px;"><strong>Does it adapt to severity?</strong> (actions stratified by SOFA quartile) — clinically we expect escalation for sicker patients.</li>
#         <li style="margin-right: 20px;"><strong>Which patients are saveable?</strong> (value landscape) — how V*(s) and the achievable return relate to severity.</li>
#     </ul>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Throughout, Value Iteration is the model-based reference; Q-Learning and SARSA should approximate it if they have converged.</p>
# </div>

# %%
counts_VI = policy_action_counts(pi_VI)
counts_QL = policy_action_counts(pi_QL)
counts_SARSA = policy_action_counts(pi_SARSA)

total_VI = counts_VI.sum()
total_QL = counts_QL.sum()
total_SARSA = counts_SARSA.sum()
frac_VI = counts_VI / total_VI
frac_QL = counts_QL / total_QL
frac_SARSA = counts_SARSA / total_SARSA
vmax_shared = float(max(frac_VI.max(), frac_QL.max(), frac_SARSA.max()))

fig, axes = plt.subplots(1, 3, figsize=(16, 5))
panel_data = [
    (frac_VI, f'Value Iteration\n(survival {vi_surv:.1f}%)'),
    (frac_QL, f'Q-Learning (seed={SEEDS[median_seed_idx]})\n(survival {ql_survs[median_seed_idx]:.1f}%)'),
    (frac_SARSA, f'SARSA (seed={SEEDS[sarsa_median_seed_idx]})\n(survival {sarsa_survs[sarsa_median_seed_idx]:.1f}%)'),
]

for ax, (frac, title) in zip(axes, panel_data):
    sns.heatmap(frac, ax=ax, annot=True, fmt='.2%', cmap='YlOrRd',
                vmin=0.0, vmax=vmax_shared, cbar=True,
                xticklabels=['F0', 'F1', 'F2', 'F3', 'F4'],
                yticklabels=['V0', 'V1', 'V2', 'V3', 'V4'])
    ax.set_xlabel('Fluid level')
    ax.set_ylabel('Vasopressor level')
    ax.set_title(title, fontweight='bold')

fig.suptitle('Action-intensity distribution under greedy policy '
             '(weighted by on-policy state visits)', fontweight='bold')
plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/configA_policy_actions.png', bbox_inches='tight')
plt.show()
# Out:
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02
# make_sepsis_env | lam=0.02 → intensity penalty active
# make_sepsis_env | sofa_bias=5.0 → mean start SOFA: 9.02

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <h3 style="margin-top: 0; margin-bottom: 10px; color: #333333; font-weight: bold;">Main Takeaways</h3>
#     <ul style="margin: 10px 40px 10px 20px; padding-left: 20px; padding-right: 0; color: #757575;">
#         <li style="margin-right: 20px;">Each cell is the share of on-policy state-visits taking a given (vasopressor, fluid) combination, so the map reflects what the policy does in the states it actually reaches.</li>
#         <li style="margin-right: 20px;">Look for mass concentrating in the low-to-moderate intensity corner, consistent with the λ = 0.02 parsimony penalty, rather than in the high–high corner.</li>
#         <li style="margin-right: 20px;">Close agreement across the VI, Q-Learning, and SARSA panels is evidence the model-free learners recovered the model-based optimum.</li>
#     </ul>
#     <h3 style="margin-top: 18px; margin-bottom: 10px; color: #333333; font-weight: bold;">Interpretation</h3>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">A systematic drift toward higher or lower intensity in the learned panels flags a genuine policy difference worth explaining clinically, rather than a convergence artefact.</p>
# </div>

# %%
sofa_full = raw._sofa_scores
sofa_nt = sofa_full[NON_TERMINAL]
quartile_cuts = np.quantile(sofa_nt, [0.25, 0.5, 0.75])
quartile_bins = np.digitize(sofa_nt, quartile_cuts)

quartile_labels = ['Q1 (least sick)', 'Q2', 'Q3', 'Q4 (most sick)']
ql_seed_label = f'Q-Learning (seed={SEEDS[median_seed_idx]})'
sarsa_seed_label = f'SARSA (seed={SEEDS[sarsa_median_seed_idx]})'
policies_to_plot = [
    ('Value Iteration', pi_VI),
    (ql_seed_label, pi_QL),
    (sarsa_seed_label, pi_SARSA),
]

xtick_labels = ['F0', 'F1', 'F2', 'F3', 'F4']
ytick_labels_left = ['V0', 'V1', 'V2', 'V3', 'V4']

fig, axes = plt.subplots(3, 4, figsize=(16, 10), sharey='row')

for row_idx, (policy_name, policy) in enumerate(policies_to_plot):
    actions_nt = policy[NON_TERMINAL]
    for q in range(4):
        in_quartile = quartile_bins == q
        a_q = actions_nt[in_quartile]
        heat_counts = np.bincount(a_q, minlength=N_ACTIONS).astype(float)
        heat_frac = heat_counts / len(a_q)
        heat_grid = heat_frac.reshape(5, 5)

        ax = axes[row_idx, q]
        if q == 0:
            ytick_labels = ytick_labels_left
        else:
            ytick_labels = False
        show_cbar = q == 3
        sns.heatmap(heat_grid, ax=ax, annot=False, cmap='YlOrRd',
                    vmin=0.0, vmax=0.30,
                    xticklabels=xtick_labels, yticklabels=ytick_labels,
                    cbar=show_cbar)

        if row_idx == 0:
            sofa_in_q = sofa_nt[in_quartile]
            sofa_lo = sofa_in_q.min()
            sofa_hi = sofa_in_q.max()
            title_text = f'{quartile_labels[q]}\nSOFA [{sofa_lo:.1f}, {sofa_hi:.1f}]'
            ax.set_title(title_text, fontsize=10)

        if row_idx == len(policies_to_plot) - 1:
            ax.set_xlabel('Fluid level')
        else:
            ax.set_xlabel('')

        if q == 0:
            ax.set_ylabel(f'{policy_name}\nVasopressor level')

fig.suptitle('Action recommendation by patient severity (SOFA quartile)',
             fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/configA_action_by_sofa.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <h3 style="margin-top: 0; margin-bottom: 10px; color: #333333; font-weight: bold;">Main Takeaways</h3>
#     <ul style="margin: 10px 40px 10px 20px; padding-left: 20px; padding-right: 0; color: #757575;">
#         <li style="margin-right: 20px;">The greedy action is broken out by SOFA quartile (Q1 least sick → Q4 most sick).</li>
#         <li style="margin-right: 20px;">The clinically expected pattern is escalation: action mass shifts to higher vasopressor and/or fluid levels as severity rises.</li>
#         <li style="margin-right: 20px;">Comparing the VI row against the QL/SARSA rows shows whether the learned policies capture this severity-dependence.</li>
#     </ul>
#     <h3 style="margin-top: 18px; margin-bottom: 10px; color: #333333; font-weight: bold;">Interpretation</h3>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">A policy that treats all quartiles alike ignores severity; one that escalates monotonically matches clinical intuition.</p>
# </div>

# %%
sofa_landscape_full = raw._sofa_scores
sofa_landscape_nt = sofa_landscape_full[NON_TERMINAL]
V_nt = V_VI_exact[NON_TERMINAL]
d0_nt = raw._d_0[NON_TERMINAL]

d0_max = d0_nt.max()
size_norm = d0_nt / d0_max
marker_sizes = 12 + 600 * size_norm

V_nt_unweighted_mean = float(V_nt.mean())

fig, axes = plt.subplots(1, 2, figsize=(13, 4.2))

j_star_label = fr'$J^* = d_0 \cdot V^* = {J_VI_exact:.3f}$'
axes[0].scatter(sofa_landscape_nt, V_nt, s=marker_sizes, alpha=0.45,
                color='steelblue', edgecolor='none')
axes[0].axhline(J_VI_exact, color='tomato', linestyle='--', linewidth=1.0,
                label=j_star_label)
axes[0].set_xlabel('SOFA score (severity)')
axes[0].set_ylabel(r'$V^*(s)$  —  expected survival probability')
axes[0].set_title(r'Value vs severity (marker size $\propto d_0(s)$)',
                  fontweight='bold')
axes[0].legend(loc='upper right')
axes[0].grid(True, alpha=0.3)

hist_j_label = fr'$J^* = {J_VI_exact:.3f}$'
hist_mean_label = f'unweighted mean = {V_nt_unweighted_mean:.3f}'
axes[1].hist(V_nt, bins=40, color='steelblue', alpha=0.85, edgecolor='none')
axes[1].axvline(J_VI_exact, color='tomato', linestyle='--', linewidth=1.5,
                label=hist_j_label)
axes[1].axvline(V_nt_unweighted_mean, color='gray', linestyle=':', linewidth=1.0,
                label=hist_mean_label)
axes[1].set_xlabel(r'$V^*(s)$')
axes[1].set_ylabel('# non-terminal states')
axes[1].set_title('Saveability distribution across states', fontweight='bold')
axes[1].legend(loc='upper left')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/configA_value_landscape.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <h3 style="margin-top: 0; margin-bottom: 10px; color: #333333; font-weight: bold;">Main Takeaways</h3>
#     <ul style="margin: 10px 40px 10px 20px; padding-left: 20px; padding-right: 0; color: #757575;">
#         <li style="margin-right: 20px;">V*(s) is the optimal expected return from state s; with +1/0 terminal rewards minus the small intensity penalty, it reads approximately as a saveability score.</li>
#         <li style="margin-right: 20px;">V* falls as SOFA severity rises; marker size ∝ d₀(s) highlights the states that actually start episodes.</li>
#         <li style="margin-right: 20px;">The dashed line is J* = d₀·V*, the d₀-weighted ceiling no Config A policy can beat.</li>
#         <li style="margin-right: 20px;">A long left tail in the saveability spread means a meaningful subset of patients are hard to save regardless of treatment.</li>
#     </ul>
#     <h3 style="margin-top: 18px; margin-bottom: 10px; color: #333333; font-weight: bold;">Interpretation</h3>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">That hard-to-save tail both caps the achievable survival rate and explains why even the optimal policy lands well below 100%.</p>
# </div>

# %% [markdown]
# # <a class='anchor' id='config-b-funcapprox'></a>
#
# <div style="background: linear-gradient(to right, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C);
#             padding: 10px; color: white; text-align: center; max-width: 98%;">
#     <center><h1 style="margin-top: 10px; margin-bottom: 4px; color: white;
#                        font-size: 32px; font-family: 'Roboto', 'Segoe UI', sans-serif;">
#         <b>3. Config B — Function Approximation</b></h1></center>
# </div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <h3 style="margin-top: 0; margin-bottom: 10px; color: #333333; font-weight: bold;">Function approximation on the clinical environment</h3>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Config B keeps the same underlying MDP but replaces the discrete state index with the 47-dimensional continuous physiological vector and adds the three clinical-reality wrappers introduced in <strong>1. Explore the Environment</strong> (episodic observation noise, episodic missing labs, and rare acute events). A Q-table is no longer possible — there is one real-valued vector per state — so the agent must generalise across states it never sees twice. We therefore move from tabular methods to function approximation.</p>
#     <h4 style="margin-top: 15px; margin-bottom: 8px; color: #4682B4; font-weight: bold;">Algorithm choice</h4>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">The two required algorithms share the Q-learning objective of Config A but differ in the approximator. Holding the learning rule fixed and changing only how Q is represented isolates a single question.</p>
#     <ul style="margin: 10px 40px 10px 20px; padding-left: 20px; padding-right: 0; color: #757575;">
#         <li style="margin-right: 20px;"><strong>B.1 — Linear Q-learning.</strong> Q(s, a) = W[a]·x + b[a], a linear function of the 47 features. This is the minimal step beyond a table and the natural bridge from Config A's tabular Q-learning: fast, transparent, and a direct measure of how much of the problem is linearly separable.</li>
#         <li style="margin-right: 20px;"><strong>B.2 — DQN.</strong> The same bootstrapped Q-learning target, but Q is a neural network trained with experience replay and a target network. It can capture non-linear interactions between physiological variables that the linear model cannot.</li>
#     </ul>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Comparing the two answers Config B's central question: does the continuous problem actually require a non-linear approximator, or do linear features suffice?</p>
#     <h4 style="margin-top: 15px; margin-bottom: 8px; color: #4682B4; font-weight: bold;">Creative extension — PPO (policy gradient)</h4>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">PPO does not learn Q-values: it directly optimises a stochastic policy with a clipped surrogate objective, belongs to a different algorithm family (on-policy, policy-gradient), and explores through action-distribution entropy rather than ε-greedy. We include it as the creative extension to test whether a fundamentally different learning principle copes better with the noisy, partially observed clinical environment.</p>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">All Config B agents use γ = 1.0 (the ICU-Sepsis convention, matching Config A — episodes terminate, so no time discounting), train for the same number of environment steps across the same three seeds (<code>SEEDS_B</code>), and are scored with the single fixed <code>evaluate_agent</code> function. Each is compared against the clinical random baseline established in <strong>1. Explore the Environment</strong>.</p>
# </div>

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">B.1 — Linear Q-learning (linear function approximation)</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Semi-gradient Q-learning with linear features: for each action a we keep a weight vector W[a] (47 values) and a bias b[a], so Q(s, a) = W[a]·x + b[a]. After each transition (x, a, r, x') we form the bootstrapped target y = r + γ·max over a' of Q(x', a') (just r at a terminal step) and take a semi-gradient step toward it. Exploration uses an ε-greedy schedule decaying linearly over the first 80% of training, mirroring Config A. We train one model per seed and evaluate a fixed-seed snapshot every <code>SNAPSHOT_EVERY</code> steps to trace the learning curve.</p>
# </div>

# %%
def linear_q_train(seed, total_steps=TOTAL_STEPS, alpha=0.01, gamma=GAMMA,
                   eps_start=1.0, eps_end=0.05, snapshot_every=SNAP_EVERY_B,
                   eval_episodes=200):
    rng = np.random.default_rng(seed)
    env = make_clinical_env_quiet()
    W = np.zeros((N_ACTIONS, 47), dtype=np.float64)
    b = np.zeros(N_ACTIONS, dtype=np.float64)
    eps_decay_steps = int(0.8 * total_steps)

    def greedy_action(obs_vec):
        q_values = W @ obs_vec + b
        action = int(np.argmax(q_values))
        return action

    snapshot_steps = []
    snapshot_returns = []
    eps_trace = []
    best_return = -np.inf
    best_W = W.copy()
    best_b = b.copy()
    step_count = 0
    obs, info = env.reset(seed=int(rng.integers(0, 100_000)))
    while step_count < total_steps:
        frac = min(1.0, step_count / eps_decay_steps)
        eps = eps_start + frac * (eps_end - eps_start)
        explore = rng.random() < eps
        if explore:
            action = int(rng.integers(0, N_ACTIONS))
        else:
            action = greedy_action(obs)
        next_obs, r, te, tr, info = env.step(action)
        q_sa = float(W[action] @ obs + b[action])
        terminal = te or tr
        if terminal:
            target = r
        else:
            q_next = W @ next_obs + b
            target = r + gamma * float(np.max(q_next))
        td_error = target - q_sa
        W[action] += alpha * td_error * obs
        b[action] += alpha * td_error
        step_count += 1
        if terminal:
            obs, info = env.reset(seed=int(rng.integers(0, 100_000)))
        else:
            obs = next_obs
        if step_count % snapshot_every == 0:
            saved_state = np.random.get_state()
            returns_snap, _, _ = evaluate_agent(greedy_action, n_episodes=eval_episodes, seed=SEED)
            np.random.set_state(saved_state)
            snap_mean = float(returns_snap.mean())
            snapshot_steps.append(step_count)
            snapshot_returns.append(snap_mean)
            eps_trace.append(eps)
            if snap_mean > best_return:
                best_return = snap_mean
                best_W = W.copy()
                best_b = b.copy()
    env.close()
    run = {
        'W': best_W,
        'b': best_b,
        'snapshot_steps': np.array(snapshot_steps),
        'snapshot_returns': np.array(snapshot_returns),
        'eps_trace': np.array(eps_trace),
        'seed': seed,
    }
    return run


linq_runs = []
for s in SEEDS_B:
    set_global_seeds(s)
    run = linear_q_train(s)
    linq_runs.append(run)
    print(f'Linear-Q seed {s}: final snapshot return = {run["snapshot_returns"][-1]:.4f}')

linq_final_list = []
for run in linq_runs:
    linq_final_list.append(float(np.max(run['snapshot_returns'])))
linq_best_idx = int(np.argmax(np.array(linq_final_list)))
W_linq = linq_runs[linq_best_idx]['W']
b_linq = linq_runs[linq_best_idx]['b']


def linq_predict(obs):
    q_values = W_linq @ obs + b_linq
    action = int(np.argmax(q_values))
    return action


set_global_seeds(SEED)
linq_returns, linq_lengths, linq_eval_info = evaluate_agent(linq_predict, n_episodes=1000, seed=SEED)
linq_mean_ret = float(linq_returns.mean())
linq_surv = float((linq_returns > 0).mean()) * 100
print(f'Linear-Q (best seed {SEEDS_B[linq_best_idx]}): mean return = {linq_mean_ret:.4f}, survival = {linq_surv:.1f}%')
# Out:
# Linear-Q seed 0: final snapshot return = 0.6850
# Linear-Q seed 1: final snapshot return = 0.6850
# Linear-Q seed 2: final snapshot return = 0.6850
# Linear-Q (best seed 0): mean return = 0.6660, survival = 66.6%

# %%
plot_learning_curve(linq_runs, 'mediumpurple', 'Linear Q-learning', 'configB_linq_curve.png', baseline=clinical_rand_mean, plots_dir=PLOTS_DIR)

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">B.2 — DQN (deep function approximation)</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">DQN keeps the Q-learning target of B.1 but represents Q(s, a) with a multi-layer perceptron (<code>MlpPolicy</code>), stabilised by an experience-replay buffer and a periodically updated target network. We use the stable-baselines3 implementation. A shared snapshot callback evaluates the greedy policy with the fixed <code>evaluate_agent</code> function at the same cadence as Linear-Q, so the learning curves are directly comparable on a common environment-steps axis. The same <code>train_sb3</code> driver is reused for PPO in B.3.</p>
# </div>

# %%
class EvalSnapshotCallback(BaseCallback):
    def __init__(self, eval_every=SNAP_EVERY_B, eval_episodes=200, eval_seed=SEED):
        super().__init__()
        self.eval_every = eval_every
        self.eval_episodes = eval_episodes
        self.eval_seed = eval_seed
        self.snapshot_steps = []
        self.snapshot_returns = []
        self.eps_trace = []
        self._last_eval = 0
        self.best_return = -np.inf
        self.best_params = None

    def _model_predict(self, obs):
        action, _ = self.model.predict(obs, deterministic=True)
        return int(action)

    def _on_step(self):
        due = (self.num_timesteps - self._last_eval) >= self.eval_every
        if due:
            self._last_eval = self.num_timesteps
            saved_state = np.random.get_state()
            returns_snap, _, _ = evaluate_agent(self._model_predict,
                                                n_episodes=self.eval_episodes, seed=self.eval_seed)
            np.random.set_state(saved_state)
            snap_mean = float(returns_snap.mean())
            self.snapshot_steps.append(self.num_timesteps)
            self.snapshot_returns.append(snap_mean)
            current_eps = getattr(self.model, 'exploration_rate', np.nan)
            self.eps_trace.append(current_eps)
            if snap_mean > self.best_return:
                self.best_return = snap_mean
                self.best_params = copy.deepcopy(self.model.get_parameters())
        keep_going = True
        return keep_going

def train_sb3(make_model, label, seeds=SEEDS_B, total_steps=TOTAL_STEPS):
    runs = []
    for s in seeds:
        set_global_seeds(s)
        train_env = Monitor(make_clinical_env_quiet())
        model = make_model(train_env, s)
        callback = EvalSnapshotCallback()
        model.learn(total_timesteps=total_steps, callback=callback)
        if callback.best_params is not None:
            model.set_parameters(callback.best_params)
        train_env.close()
        run = {
            'model': model,
            'snapshot_steps': np.array(callback.snapshot_steps),
            'snapshot_returns': np.array(callback.snapshot_returns),
            'eps_trace': np.array(callback.eps_trace),
            'seed': s,
        }
        runs.append(run)
        print(f'{label} seed {s}: final snapshot return = {run["snapshot_returns"][-1]:.4f}')
    return runs

def sb3_predict_factory(model):
    def predict(obs):
        action, _ = model.predict(obs, deterministic=True)
        return int(action)
    return predict

def make_dqn(env, seed):
    model = DQN(
        'MlpPolicy', env,
        gamma=GAMMA,
        learning_rate=5e-4,
        buffer_size=100_000,
        learning_starts=1_000,
        batch_size=64,
        target_update_interval=1_000,
        exploration_fraction=0.2,
        exploration_final_eps=0.05,
        seed=seed,
        verbose=0,
    )
    return model

dqn_runs = train_sb3(make_dqn, 'DQN')
dqn_best = best_run(dqn_runs)
dqn_model = dqn_best['model']
dqn_predict = sb3_predict_factory(dqn_model)

set_global_seeds(SEED)
dqn_returns, dqn_lengths, dqn_eval_info = evaluate_agent(dqn_predict, n_episodes=1000, seed=SEED)
dqn_mean_ret = float(dqn_returns.mean())
dqn_surv = float((dqn_returns > 0).mean()) * 100
print(f'DQN (best seed {dqn_best["seed"]}): mean return = {dqn_mean_ret:.4f}, survival = {dqn_surv:.1f}%')
# Out:
# DQN seed 0: final snapshot return = 0.5964
# DQN seed 1: final snapshot return = 0.6145
# DQN seed 2: final snapshot return = 0.6493
# DQN (best seed 2): mean return = 0.6078, survival = 67.4%

# %%
plot_learning_curve(dqn_runs, 'steelblue', 'DQN', 'configB_dqn_curve.png', baseline=clinical_rand_mean, plots_dir=PLOTS_DIR)

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">B.3 — Creative extension: PPO (policy gradient)</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <h4 style="margin-top: 15px; margin-bottom: 8px; color: #4682B4; font-weight: bold;">Motivation</h4>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">B.1 and B.2 are both value-based and off-policy: they learn Q and act greedily. PPO is the opposite design — an on-policy actor that optimises a stochastic policy directly with a clipped objective, exploring through the entropy of its action distribution rather than an ε schedule. Because it never bootstraps a max over noisy Q estimates, we expected it to be more stable under the clinical wrappers' observation noise and partial observability.</p>
#     <h4 style="margin-top: 15px; margin-bottom: 8px; color: #4682B4; font-weight: bold;">What we test</h4>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Whether the algorithm family itself, and not the approximator alone, changes behaviour and final performance on the same environment, same budget, and same fixed evaluation. The result is discussed alongside the value-based agents in B.4.</p>
# </div>

# %%
def make_ppo(env, seed):
    model = PPO(
        'MlpPolicy', env,
        gamma=GAMMA,
        n_steps=2048,
        batch_size=64,
        n_epochs=10,
        gae_lambda=0.95,
        ent_coef=0.01,
        learning_rate=3e-4,
        seed=seed,
        verbose=0,
    )
    return model


ppo_runs = train_sb3(make_ppo, 'PPO')
ppo_best = best_run(ppo_runs)
ppo_model = ppo_best['model']
ppo_predict = sb3_predict_factory(ppo_model)

set_global_seeds(SEED)
ppo_returns, ppo_lengths, ppo_eval_info = evaluate_agent(ppo_predict, n_episodes=1000, seed=SEED)
ppo_mean_ret = float(ppo_returns.mean())
ppo_surv = float((ppo_returns > 0).mean()) * 100
print(f'PPO (best seed {ppo_best["seed"]}): mean return = {ppo_mean_ret:.4f}, survival = {ppo_surv:.1f}%')
# Out:
# PPO seed 0: final snapshot return = 0.6155
# PPO seed 1: final snapshot return = 0.6187
# PPO seed 2: final snapshot return = 0.5469
# PPO (best seed 0): mean return = 0.6148, survival = 67.5%

# %%
plot_learning_curve(ppo_runs, 'seagreen', 'PPO', 'configB_ppo_curve.png', baseline=clinical_rand_mean, plots_dir=PLOTS_DIR)

# %% [markdown]
# ## <div style="display:inline-block; background:linear-gradient(to right, #4682B4, #2C5F8A, #1A3D5C); color:#FFFFFF; font-weight:bold; font-size:18px; padding:7px 18px; border-radius:6px; font-family:'Roboto','Segoe UI','Calibri','Open Sans',sans-serif;">B.4 — Config B results and interpretation</div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">We compare the three Config B agents against each other and against the clinical random baseline. All numbers come from the fixed <code>evaluate_agent</code> function (1000 episodes, fixed seed). We report mean return, survival rate with a bootstrap 95% confidence interval, mean episode length, and a convergence metric — the number of environment steps a model's mean learning curve takes to first reach a shared target return. Analytical J is not available here because, unlike Config A, there is no tabular model of the value function under function approximation. The two interpretability figures connect the learned policies back to the clinical decision (vasopressor vs IV fluid) and to patient severity (SOFA).</p>
# </div>

# %%
linq_curve = mean_curve(linq_runs)
dqn_curve = mean_curve(dqn_runs)
ppo_curve = mean_curve(ppo_runs)

fig, ax = plt.subplots(figsize=(11, 5))
ax.plot(linq_runs[0]['snapshot_steps'], linq_curve, color='mediumpurple', linewidth=2.0, marker='o', markersize=3, label='Linear-Q')
ax.plot(dqn_runs[0]['snapshot_steps'], dqn_curve, color='steelblue', linewidth=2.0, marker='o', markersize=3, label='DQN')
ax.plot(ppo_runs[0]['snapshot_steps'], ppo_curve, color='seagreen', linewidth=2.0, marker='o', markersize=3, label='PPO')
ax.axhline(clinical_rand_mean, color='gray', linestyle=':', linewidth=1.5, label=f'Random baseline ({clinical_rand_mean:.3f})')
ax.set_xlabel('Environment steps')
ax.set_ylabel('Eval return (mean of 3 seeds)')
ax.set_title('Config B learning curves - Linear-Q vs DQN vs PPO', fontweight='bold')
ax.legend(loc='lower right')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/configB_learning_curves.png', bbox_inches='tight')
plt.show()

# %%
best_final = max(float(linq_curve[-1]), float(dqn_curve[-1]), float(ppo_curve[-1]))
target_return = clinical_rand_mean + 0.9 * (best_final - clinical_rand_mean)

linq_conv = steps_to_threshold(linq_runs[0]['snapshot_steps'], linq_curve, target_return)
dqn_conv = steps_to_threshold(dqn_runs[0]['snapshot_steps'], dqn_curve, target_return)
ppo_conv = steps_to_threshold(ppo_runs[0]['snapshot_steps'], ppo_curve, target_return)

rand_ret_std = float(clinical_rand_returns.std())
linq_ret_std = float(linq_returns.std())
dqn_ret_std = float(dqn_returns.std())
ppo_ret_std = float(ppo_returns.std())

rand_lo, rand_hi = bootstrap_survival_ci(clinical_rand_returns)
linq_lo, linq_hi = bootstrap_survival_ci(linq_returns)
dqn_lo, dqn_hi = bootstrap_survival_ci(dqn_returns)
ppo_lo, ppo_hi = bootstrap_survival_ci(ppo_returns)

linq_dret = linq_mean_ret - clinical_rand_mean
dqn_dret = dqn_mean_ret - clinical_rand_mean
ppo_dret = ppo_mean_ret - clinical_rand_mean
linq_dsurv = linq_surv - clinical_rand_surv
dqn_dsurv = dqn_surv - clinical_rand_surv
ppo_dsurv = ppo_surv - clinical_rand_surv

algorithm_col = ['Random', 'Linear-Q', 'DQN', 'PPO']
return_col = [
    f'{clinical_rand_mean:.4f} +/- {rand_ret_std:.4f}',
    f'{linq_mean_ret:.4f} +/- {linq_ret_std:.4f}',
    f'{dqn_mean_ret:.4f} +/- {dqn_ret_std:.4f}',
    f'{ppo_mean_ret:.4f} +/- {ppo_ret_std:.4f}',
]
survival_col = [
    f'{clinical_rand_surv:.1f}% [{rand_lo:.1f}, {rand_hi:.1f}]',
    f'{linq_surv:.1f}% [{linq_lo:.1f}, {linq_hi:.1f}]',
    f'{dqn_surv:.1f}% [{dqn_lo:.1f}, {dqn_hi:.1f}]',
    f'{ppo_surv:.1f}% [{ppo_lo:.1f}, {ppo_hi:.1f}]',
]
length_col = [
    f'{clinical_rand_lengths.mean():.1f}',
    f'{linq_lengths.mean():.1f}',
    f'{dqn_lengths.mean():.1f}',
    f'{ppo_lengths.mean():.1f}',
]
convergence_col = ['-', fmt_conv(linq_conv), fmt_conv(dqn_conv), fmt_conv(ppo_conv)]
dret_col = ['-', f'{linq_dret:+.4f}', f'{dqn_dret:+.4f}', f'{ppo_dret:+.4f}']
dsurv_col = ['-', f'{linq_dsurv:+.1f} pp', f'{dqn_dsurv:+.1f} pp', f'{ppo_dsurv:+.1f} pp']

results_B_df = pd.DataFrame({
    'Algorithm': algorithm_col,
    'Mean return +/- std': return_col,
    'Survival % [95% CI]': survival_col,
    'Mean ep length': length_col,
    'Convergence (to target return)': convergence_col,
    'd return vs random': dret_col,
    'd survival vs random': dsurv_col,
})
print(f'Shared target return for convergence column: {target_return:.4f}')
display(results_B_df)
# Out:
# Shared target return for convergence column: 0.6724
#   Algorithm Mean return +/- std Survival % [95% CI] Mean ep length  \
# 0    Random   0.5587 +/- 0.4770  65.0% [61.9, 68.2]            9.2
# 1  Linear-Q   0.6660 +/- 0.4716  66.6% [63.7, 69.7]            9.3
# 2       DQN   0.6078 +/- 0.4691  67.4% [64.3, 70.1]            9.3
# 3       PPO   0.6148 +/- 0.4671  67.5% [64.7, 70.2]            8.9
#
#   Convergence (to target return) d return vs random d survival vs random
# 0                              -                  -                    -
# 1                   40,000 steps            +0.1073              +1.6 pp
# 2                    not reached            +0.0491              +2.4 pp
# 3                    not reached            +0.0561              +2.5 pp

# %%
dataset = [clinical_rand_returns, linq_returns, dqn_returns, ppo_returns]
labels = ['Random', 'Linear-Q', 'DQN', 'PPO']
colors = ['gray', 'mediumpurple', 'steelblue', 'seagreen']

fig, ax = plt.subplots(figsize=(11, 5))
positions = np.arange(1, len(dataset) + 1)
parts = ax.violinplot(dataset, positions=positions, showmeans=True, showextrema=False)
for body, color in zip(parts['bodies'], colors):
    body.set_facecolor(color)
    body.set_alpha(0.5)
parts['cmeans'].set_color('black')

survivals = [clinical_rand_surv, linq_surv, dqn_surv, ppo_surv]
for pos, surv in zip(positions, survivals):
    ax.text(pos, 1.08, f'{surv:.0f}%', ha='center', va='bottom', fontsize=9, fontweight='bold')

ax.set_xticks(positions)
ax.set_xticklabels(labels)
ax.set_ylabel('Episode return (1000 eval episodes)')
ax.set_title('Config B return distributions (survival % annotated above)', fontweight='bold')
ax.grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/configB_return_distribution.png', bbox_inches='tight')
plt.show()

# %%
agent_predicts = [linq_predict, dqn_predict, ppo_predict]
agent_names = ['Linear-Q', 'DQN', 'PPO']
level_labels = ['none', 'low', 'med', 'high', 'max']

fig, axes = plt.subplots(1, 3, figsize=(15, 4.4))
for ax, predict_fn, name in zip(axes, agent_predicts, agent_names):
    grid = policy_action_grid(predict_fn)
    sns.heatmap(grid, ax=ax, cmap='magma', annot=True, fmt='.2f', cbar=False,
                xticklabels=level_labels, yticklabels=level_labels)
    ax.set_title(f'{name} action frequencies', fontweight='bold')
    ax.set_xlabel('IV fluid level')
    ax.set_ylabel('Vasopressor level')
plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/configB_policy_actions.png', bbox_inches='tight')
plt.show()

# %%
sofa_bins = np.array([0, 4, 8, 12, 24])
bin_centers = []
for k in range(len(sofa_bins) - 1):
    center = (sofa_bins[k] + sofa_bins[k + 1]) / 2.0
    bin_centers.append(center)
bin_centers = np.array(bin_centers)

fig, axes = plt.subplots(1, 2, figsize=(14, 4.6))
for predict_fn, name, color in zip(agent_predicts, agent_names, ['mediumpurple', 'steelblue', 'seagreen']):
    data = action_by_sofa(predict_fn)
    bin_idx = np.digitize(data['sofa'], sofa_bins[1:-1])
    vaso_by_bin = []
    fluid_by_bin = []
    for k in range(len(bin_centers)):
        in_bin = bin_idx == k
        if in_bin.sum() > 0:
            vaso_by_bin.append(data['vaso'][in_bin].mean())
            fluid_by_bin.append(data['fluid'][in_bin].mean())
        else:
            vaso_by_bin.append(np.nan)
            fluid_by_bin.append(np.nan)
    axes[0].plot(bin_centers, vaso_by_bin, marker='o', color=color, label=name)
    axes[1].plot(bin_centers, fluid_by_bin, marker='o', color=color, label=name)

axes[0].set_title('Mean vasopressor level vs severity', fontweight='bold')
axes[0].set_xlabel('Start SOFA score')
axes[0].set_ylabel('Mean vasopressor level (0-4)')
axes[0].legend()
axes[0].grid(True, alpha=0.3)
axes[1].set_title('Mean IV fluid level vs severity', fontweight='bold')
axes[1].set_xlabel('Start SOFA score')
axes[1].set_ylabel('Mean IV fluid level (0-4)')
axes[1].legend()
axes[1].grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/configB_action_by_sofa.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # <a class='anchor' id='comparison'></a>
#
# <div style="background: linear-gradient(to right, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C);
#             padding: 10px; color: white; text-align: center; max-width: 98%;">
#     <center><h1 style="margin-top: 10px; margin-bottom: 4px; color: white;
#                        font-size: 32px; font-family: 'Roboto', 'Segoe UI', sans-serif;">
#         <b>4. Comparison of Config A and Config B</b></h1></center>
# </div>

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <h3 style="margin-top: 0; margin-bottom: 10px; color: #333333; font-weight: bold;">Comparing the two regimes</h3>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Config A and Config B share the same MDP, so the contrast is purely about observation and method class: a tabular agent on a clean discrete state index versus function approximators on a noisy, partially observed 47-dimensional vector. A direct survival-number comparison is unfair, because Config B also carries the clinical-reality wrappers (observation noise, missing labs, rare acute events).</p>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">To separate the two effects we add one bridge experiment: we run Config A's optimal Value-Iteration policy <code>pi_VI</code> on the clinical environment, reading the true discrete state at each step. This oracle agent is immune to observation corruption (it never looks at the 47-dim vector) but still suffers the irreducible acute-event mortality. It therefore upper-bounds what any Config B agent could achieve with perfect state information, and the gap between it and the deep agents measures the cost of learning from raw, corrupted observations.</p>
# </div>

# %%
set_global_seeds(SEED)
vi_clinical_returns, vi_clinical_lengths = evaluate_tabular_on_clinical(pi_VI)
vi_clinical_mean = float(vi_clinical_returns.mean())
vi_clinical_surv = float((vi_clinical_returns > 0).mean()) * 100

comp_algos = ['VI (Config A, clean discrete)', 'VI policy on clinical env', 'Linear-Q (Config B)', 'DQN (Config B)', 'PPO (Config B)']
comp_obs = ['discrete index', 'discrete (oracle), clinical dynamics', 'continuous 47-dim', 'continuous 47-dim', 'continuous 47-dim']
comp_class = ['tabular DP', 'tabular policy, deployed', 'linear FA', 'deep FA', 'policy gradient']
comp_returns = [vi_mean_ret, vi_clinical_mean, linq_mean_ret, dqn_mean_ret, ppo_mean_ret]
comp_surv = [vi_surv, vi_clinical_surv, linq_surv, dqn_surv, ppo_surv]

return_str_col = []
surv_str_col = []
for ret_value in comp_returns:
    return_str_col.append(f'{ret_value:.4f}')
for surv_value in comp_surv:
    surv_str_col.append(f'{surv_value:.1f}%')

comparison_df = pd.DataFrame({
    'Setting': comp_algos,
    'Observation': comp_obs,
    'Method': comp_class,
    'Mean return': return_str_col,
    'Survival %': surv_str_col,
})
display(comparison_df)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
x_pos = np.arange(len(comp_algos))
bar_colors = ['darkgreen', 'mediumseagreen', 'mediumpurple', 'steelblue', 'seagreen']
axes[0].bar(x_pos, comp_surv, color=bar_colors, alpha=0.85)
axes[0].set_ylabel('Survival rate (%)')
axes[0].set_title('Survival: Config A vs Config B', fontweight='bold')
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(comp_algos, rotation=30, ha='right', fontsize=8)
axes[0].grid(True, alpha=0.3, axis='y')
axes[1].bar(x_pos, comp_returns, color=bar_colors, alpha=0.85)
axes[1].set_ylabel('Mean return')
axes[1].set_title('Mean return: Config A vs Config B', fontweight='bold')
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(comp_algos, rotation=30, ha='right', fontsize=8)
axes[1].grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.savefig(f'{PLOTS_DIR}/comparison_AB.png', bbox_inches='tight')
plt.show()
# Out:
#                          Setting                           Observation  \
# 0  VI (Config A, clean discrete)                        discrete index
# 1      VI policy on clinical env  discrete (oracle), clinical dynamics
# 2            Linear-Q (Config B)                     continuous 47-dim
# 3                 DQN (Config B)                     continuous 47-dim
# 4                 PPO (Config B)                     continuous 47-dim
#
#                      Method Mean return Survival %
# 0                tabular DP      0.7507      78.8%
# 1  tabular policy, deployed      0.7485      78.5%
# 2                 linear FA      0.6660      66.6%
# 3                   deep FA      0.6078      67.4%
# 4           policy gradient      0.6148      67.5%

# %% [markdown]
# <div style="background-color: #F2F2F2; padding: 15px; margin-right: 30px; border-left: 5px solid; border-image: linear-gradient(to bottom, #A8C5E0, #4682B4, #2C5F8A, #1A3D5C) 1; border-radius: 5px; max-width: 95%;">
#     <h3 style="margin-top: 0; margin-bottom: 10px; color: #333333; font-weight: bold;">Main Takeaways</h3>
#     <ul style="margin: 10px 40px 10px 20px; padding-left: 20px; padding-right: 0; color: #757575;">
#         <li style="margin-right: 20px;">When the true state is a small discrete index and the full MDP is known, exact tabular methods (Value Iteration) are optimal and cheap; deep RL would add nothing.</li>
#         <li style="margin-right: 20px;">Once the observation is a high-dimensional continuous vector, the agent never sees the same state twice, a table is impossible, and function approximation becomes mandatory.</li>
#         <li style="margin-right: 20px;">The "VI policy on clinical env" row keeps perfect state information and loses ground to the Config A baseline only through irreducible acute-event mortality.</li>
#         <li style="margin-right: 20px;">The Config B learners additionally cope with observation noise, missing labs, and generalisation from raw features; the Linear-Q vs DQN gap measures how much residual structure is non-linear, and PPO tests whether a different algorithm family closes it.</li>
#     </ul>
#     <h3 style="margin-top: 18px; margin-bottom: 10px; color: #333333; font-weight: bold;">Interpretation</h3>
#     <p style="margin: 10px 0; margin-right: 40px; color: #757575;">Method choice should follow the observation model. Prefer exact tabular methods when a faithful discrete model exists; adopt deep RL only when the observation space forces generalisation, accepting reduced interpretability and sensitivity to data-quality failures in return.</p>
# </div>
